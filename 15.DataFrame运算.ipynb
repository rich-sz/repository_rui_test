# %%
import pandas as pd
import numpy as np

# %%
# 读取文件
data = pd.read_csv("./data/stock_day.csv")
# 删除一些列，让数据更简单些，再去做后面的操作
data = data.drop(["ma5","ma10","ma20","v_ma5","v_ma10","v_ma20"], axis=1)
data
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# ...           ...    ...    ...    ...        ...           ...       ...
# 2015-03-06  13.17  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05  12.88  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04  12.80  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03  12.52  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02  12.25  12.67  12.52  12.20   96291.73          0.32      2.62
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# ...

# %% [markdown]
# # 算术运算符
#
# - add
#
# - sub

# %%
# 把这一列所有数据加1
data['open'].add(1)
# Out:
# 2018-02-27    24.53
# 2018-02-26    23.80
# 2018-02-23    23.88
# 2018-02-22    23.25
# 2018-02-14    22.49
#               ...
# 2015-03-06    14.17
# 2015-03-05    13.88
# 2015-03-04    13.80
# 2015-03-03    13.52
# 2015-03-02    13.25
# Name: open, Length: 643, dtype: float64

# %%
# 把所有数据都加1
data+1
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  24.53  26.88  25.16  24.53   95579.03          1.63      3.68
# 2018-02-26  23.80  24.78  24.53  23.80   60986.11          1.69      4.02
# 2018-02-23  23.88  24.37  23.82  23.71   52915.01          1.54      3.42
# 2018-02-22  23.25  23.76  23.28  23.02   36106.01          1.36      2.64
# 2018-02-14  22.49  22.99  22.92  22.48   23332.04          1.44      3.05
# ...           ...    ...    ...    ...        ...           ...       ...
# 2015-03-06  14.17  15.48  15.28  14.13  179832.72          2.12      9.51
# 2015-03-05  13.88  14.45  14.16  13.87   93181.39          1.26      3.02
# 2015-03-04  13.80  13.92  13.90  13.61   67076.44          1.20      2.57
# 2015-03-03  13.52  14.06  13.70  13.52  139072.61          1.18      2.44
# 2015-03-02  13.25  13.67  13.52  13.20   96292.73          1.32      3.62
#
#             turnover
# 2018-02-27      3.39
# 2018-02-26      2.53
# ...

# %%
# 减1
data['open'].sub(1)
# Out:
# 2018-02-27    22.53
# 2018-02-26    21.80
# 2018-02-23    21.88
# 2018-02-22    21.25
# 2018-02-14    20.49
#               ...
# 2015-03-06    12.17
# 2015-03-05    11.88
# 2015-03-04    11.80
# 2015-03-03    11.52
# 2015-03-02    11.25
# Name: open, Length: 643, dtype: float64

# %% [markdown]
# # 逻辑运算符

# %% [markdown]
# - 逻辑运算符

# %%
data["open"] > 23
# Out:
# 2018-02-27     True
# 2018-02-26    False
# 2018-02-23    False
# 2018-02-22    False
# 2018-02-14    False
#               ...
# 2015-03-06    False
# 2015-03-05    False
# 2015-03-04    False
# 2015-03-03    False
# 2015-03-02    False
# Name: open, Length: 643, dtype: bool

# %%
data>23
# Out:
#              open   high  close    low  volume  price_change  p_change  \
# 2018-02-27   True   True   True   True    True         False     False
# 2018-02-26  False   True   True  False    True         False     False
# 2018-02-23  False   True  False  False    True         False     False
# 2018-02-22  False  False  False  False    True         False     False
# 2018-02-14  False  False  False  False    True         False     False
# ...           ...    ...    ...    ...     ...           ...       ...
# 2015-03-06  False  False  False  False    True         False     False
# 2015-03-05  False  False  False  False    True         False     False
# 2015-03-04  False  False  False  False    True         False     False
# 2015-03-03  False  False  False  False    True         False     False
# 2015-03-02  False  False  False  False    True         False     False
#
#             turnover
# 2018-02-27     False
# 2018-02-26     False
# 2018-02-23     False
# 2018-02-22     False
# ...

# %%
data[data["open"] > 23]
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-01  23.71  23.86  22.42  22.22   66414.64         -1.30     -5.48
# 2018-01-31  23.85  23.98  23.72  23.31   49155.02         -0.11     -0.46
# 2018-01-30  23.71  24.08  23.83  23.70   32420.43          0.05      0.21
# 2018-01-29  24.40  24.63  23.77  23.72   65469.81         -0.73     -2.98
# ...           ...    ...    ...    ...        ...           ...       ...
# 2015-05-21  27.50  28.22  28.22  26.50  121190.11          2.57     10.02
# 2015-05-20  24.10  25.65  25.65  24.10  164143.16          2.33      9.99
# 2015-05-19  23.68  23.69  23.32  22.47   82945.73          0.25      1.08
# 2015-04-16  24.63  25.21  22.97  21.94  221070.31         -1.41     -5.78
# 2015-04-15  23.45  25.56  24.38  23.40  250311.59          1.14      4.91
#
#             turnover
# 2018-02-27      2.39
# 2018-02-01      1.66
# ...

# %% [markdown]
# - 多个逻辑运算符

# %%
data[(data["open"] > 23) & (data["open"] < 24)]
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-01  23.71  23.86  22.42  22.22   66414.64         -1.30     -5.48
# 2018-01-31  23.85  23.98  23.72  23.31   49155.02         -0.11     -0.46
# 2018-01-30  23.71  24.08  23.83  23.70   32420.43          0.05      0.21
# 2018-01-16  23.40  24.60  24.40  23.30  101295.42          0.96      4.10
# 2018-01-12  23.70  25.15  24.24  23.42  120303.53          0.56      2.37
# 2018-01-11  23.67  23.85  23.67  23.21   48525.75         -0.12     -0.50
# 2017-12-22  23.21  23.39  22.99  22.90   28394.00         -0.21     -0.91
# 2017-12-21  23.39  23.50  23.21  22.86   34005.55         -0.11     -0.47
# 2017-12-20  23.61  23.96  23.33  23.20   43368.92         -0.14     -0.60
# 2017-12-19  23.23  23.66  23.46  23.23   43068.70          0.31      1.34
# 2017-12-15  23.40  23.40  23.00  22.85   43442.15         -0.46     -1.96
# ...

# %%
(data["open"] > 23) & (data["open"] < 24)
# Out:
# 2018-02-27     True
# 2018-02-26    False
# 2018-02-23    False
# 2018-02-22    False
# 2018-02-14    False
#               ...
# 2015-03-06    False
# 2015-03-05    False
# 2015-03-04    False
# 2015-03-03    False
# 2015-03-02    False
# Name: open, Length: 643, dtype: bool

# %% [markdown]
# # 逻辑运算函数
#
# - query(expr)
#
#   expr:查询字符串
#
# - isin(values)
#
#   例如判断'open'是否为23.53和23.85

# %%
# 查询
data.query("open<24 & open>23")
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-01  23.71  23.86  22.42  22.22   66414.64         -1.30     -5.48
# 2018-01-31  23.85  23.98  23.72  23.31   49155.02         -0.11     -0.46
# 2018-01-30  23.71  24.08  23.83  23.70   32420.43          0.05      0.21
# 2018-01-16  23.40  24.60  24.40  23.30  101295.42          0.96      4.10
# 2018-01-12  23.70  25.15  24.24  23.42  120303.53          0.56      2.37
# 2018-01-11  23.67  23.85  23.67  23.21   48525.75         -0.12     -0.50
# 2017-12-22  23.21  23.39  22.99  22.90   28394.00         -0.21     -0.91
# 2017-12-21  23.39  23.50  23.21  22.86   34005.55         -0.11     -0.47
# 2017-12-20  23.61  23.96  23.33  23.20   43368.92         -0.14     -0.60
# 2017-12-19  23.23  23.66  23.46  23.23   43068.70          0.31      1.34
# 2017-12-15  23.40  23.40  23.00  22.85   43442.15         -0.46     -1.96
# ...

# %%
data
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# ...           ...    ...    ...    ...        ...           ...       ...
# 2015-03-06  13.17  14.48  14.28  13.13  179831.72          1.12      8.51
# 2015-03-05  12.88  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-04  12.80  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-03  12.52  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-02  12.25  12.67  12.52  12.20   96291.73          0.32      2.62
#
#             turnover
# 2018-02-27      2.39
# 2018-02-26      1.53
# ...

# %%
data[data["open"].isin([23.53, 23.85])]
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-01-31  23.85  23.98  23.72  23.31   49155.02         -0.11     -0.46
# 2017-07-26  23.53  23.92  23.40  22.85  110276.48         -0.30     -1.27
# 2015-12-18  23.53  24.66  23.99  23.43  109230.05          0.65      2.79
# 2015-11-26  23.85  24.08  23.53  23.50   51446.29         -0.31     -1.30
#
#             turnover
# 2018-02-27      2.39
# 2018-01-31      1.23
# 2017-07-26      2.76
# 2015-12-18      3.74
# 2015-11-26      1.76

# %% [markdown]
# # 统计运算
#
# - describe 可以直接统计很多结果 count, mean, std, min, max 等
#
# | `count`  | Number of non-NA observations                  |
# | -------- | ---------------------------------------------- |
# | `sum`    | **Sum of values**                              |
# | `mean`   | **Mean of values**                             |
# | `median` | Arithmetic median of values                    |
# | `min`    | **Minimum**                                    |
# | `max`    | **Maximum**                                    |
# | `mode`   | Mode                                           |
# | `abs`    | Absolute Value                                 |
# | `prod`   | Product of values                              |
# | `std`    | **Bessel-corrected sample standard deviation** |
# | `var`    | **Unbiased variance**                          |
# | `idxmax` | compute the index labels with the maximum      |
# | `idxmin` | compute the index labels with the minimum      |

# %%
data.describe()
# Out:
#              open        high       close         low         volume  \
# count  643.000000  643.000000  643.000000  643.000000     643.000000
# mean    21.272706   21.900513   21.336267   20.771835   99905.519114
# std      3.930973    4.077578    3.942806    3.791968   73879.119354
# min     12.250000   12.670000   12.360000   12.200000    1158.120000
# 25%     19.000000   19.500000   19.045000   18.525000   48533.210000
# 50%     21.440000   21.970000   21.450000   20.980000   83175.930000
# 75%     23.400000   24.065000   23.415000   22.850000  127580.055000
# max     34.990000   36.350000   35.210000   34.010000  501915.410000
#
#        price_change    p_change    turnover
# count    643.000000  643.000000  643.000000
# mean       0.018802    0.190280    2.936190
# std        0.898476    4.079698    2.079375
# min       -3.520000  -10.030000    0.040000
# 25%       -0.390000   -1.850000    1.360000
# 50%        0.050000    0.260000    2.500000
# ...

# %% [markdown]
# - max()、min()  # 使用统计函数：0 代表列求结果， 1 代表行求统计结果

# %%
# data.max(1)

# %%
data.head(20)
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# 2018-02-13  21.40  21.90  21.48  21.31   30802.45          0.28      1.32
# 2018-02-12  20.70  21.40  21.19  20.63   32445.39          0.82      4.03
# 2018-02-09  21.20  21.46  20.36  20.19   54304.01         -1.50     -6.86
# 2018-02-08  21.79  22.09  21.88  21.75   27068.16          0.09      0.41
# 2018-02-07  22.69  23.11  21.80  21.29   53853.25         -0.50     -2.24
# 2018-02-06  22.80  23.55  22.29  22.20   55555.00         -0.97     -4.17
# 2018-02-05  22.45  23.39  23.27  22.25   52341.39          0.65      2.87
# ...

# %%
data.head(20).mode()
# Out:
#      open   high  close    low     volume  price_change  p_change  turnover
# 0   22.80  21.40  20.36  20.19   23331.04         -1.50     -6.86      0.81
# 1   23.71  21.46  21.19  20.63   27068.16         -1.30     -5.48       NaN
# 2     NaN  21.90  21.48  21.29   30802.45         -0.97     -4.17       NaN
# 3     NaN  21.99  21.80  21.31   32420.43         -0.93     -3.68       NaN
# 4     NaN  22.09  21.88  21.48   32445.39         -0.73     -2.98       NaN
# 5     NaN  22.70  21.92  21.53   33242.11         -0.50     -2.24       NaN
# 6     NaN  22.76  22.28  21.75   36105.01         -0.20     -0.79       NaN
# 7     NaN  23.11  22.29  22.02   49155.02         -0.11     -0.46       NaN
# 8     NaN  23.37  22.42  22.20   50601.83          0.05      0.21       NaN
# 9     NaN  23.39  22.62  22.22   52341.39          0.09      0.41       NaN
# 10    NaN  23.55  22.82  22.25   52914.01          0.11      0.45       NaN
# ...

# %%
data.max(0)
# Out:
# open                34.99
# high                36.35
# close               35.21
# low                 34.01
# volume          501915.41
# price_change         3.03
# p_change            10.03
# turnover            12.56
# dtype: float64

# %% [markdown]
# - std()、var()  var:方差  std:标准差

# %%
data.var(0)
# Out:
# open            1.545255e+01
# high            1.662665e+01
# close           1.554572e+01
# low             1.437902e+01
# volume          5.458124e+09
# price_change    8.072595e-01
# p_change        1.664394e+01
# turnover        4.323800e+00
# dtype: float64

# %%
data.std(0)
# Out:
# open                3.930973
# high                4.077578
# close               3.942806
# low                 3.791968
# volume          73879.119354
# price_change        0.898476
# p_change            4.079698
# turnover            2.079375
# dtype: float64

# %% [markdown]
# - median()：中位数

# %%
df = pd.DataFrame({'COL1' : [2,3,4,5,4,2],
                   'COL2' : [0,1,2,3,4,2]})
# 排序之后的中位数
df.median()
# Out:
# COL1    3.5
# COL2    2.0
# dtype: float64

# %%
df
# Out:
#    COL1  COL2
# 0     2     0
# 1     3     1
# 2     4     2
# 3     5     3
# 4     4     4
# 5     2     2

# %% [markdown]
# - idxmax(axis)、idxmin(axis) 最大和最小值得索引  axis:0列  1行

# %%
# 求出最大值的位置
data.idxmax(axis=0)
# Out:
# open            2015-06-15
# high            2015-06-10
# close           2015-06-12
# low             2015-06-12
# volume          2017-10-26
# price_change    2015-06-09
# p_change        2015-08-28
# turnover        2017-10-26
# dtype: object

# %%
# 求出最小值的位置
data.idxmin(axis=0)
# Out:
# open            2015-03-02
# high            2015-03-02
# close           2015-09-02
# low             2015-03-02
# volume          2016-07-06
# price_change    2015-06-15
# p_change        2015-09-01
# turnover        2016-07-06
# dtype: object

# %% [markdown]
# # 累计统计函数
#
# | 函数      | 作用                        |
# | --------- | --------------------------- |
# | `cumsum`  | **计算前1/2/3/…/n个数的和** |
# | `cummax`  | 计算前1/2/3/…/n个数的最大值 |
# | `cummin`  | 计算前1/2/3/…/n个数的最小值 |
# | `cumprod` | 计算前1/2/3/…/n个数的积     |

# %%
# 排序之后，进行累计求和
dd = data.sort_index()
dd
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2015-03-02  12.25  12.67  12.52  12.20   96291.73          0.32      2.62
# 2015-03-03  12.52  13.06  12.70  12.52  139071.61          0.18      1.44
# 2015-03-04  12.80  12.92  12.90  12.61   67075.44          0.20      1.57
# 2015-03-05  12.88  13.45  13.16  12.87   93180.39          0.26      2.02
# 2015-03-06  13.17  14.48  14.28  13.13  179831.72          1.12      8.51
# ...           ...    ...    ...    ...        ...           ...       ...
# 2018-02-14  21.49  21.99  21.92  21.48   23331.04          0.44      2.05
# 2018-02-22  22.25  22.76  22.28  22.02   36105.01          0.36      1.64
# 2018-02-23  22.88  23.37  22.82  22.71   52914.01          0.54      2.42
# 2018-02-26  22.80  23.78  23.53  22.80   60985.11          0.69      3.02
# 2018-02-27  23.53  25.88  24.16  23.53   95578.03          0.63      2.68
#
#             turnover
# 2015-03-02      3.30
# 2015-03-03      4.76
# ...

# %%
dd.cummax(axis=0)
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# 2015-03-02  12.25  12.67  12.52  12.20   96291.73          0.32      2.62
# 2015-03-03  12.52  13.06  12.70  12.52  139071.61          0.32      2.62
# 2015-03-04  12.80  13.06  12.90  12.61  139071.61          0.32      2.62
# 2015-03-05  12.88  13.45  13.16  12.87  139071.61          0.32      2.62
# 2015-03-06  13.17  14.48  14.28  13.13  179831.72          1.12      8.51
# ...           ...    ...    ...    ...        ...           ...       ...
# 2018-02-14  34.99  36.35  35.21  34.01  501915.41          3.03     10.03
# 2018-02-22  34.99  36.35  35.21  34.01  501915.41          3.03     10.03
# 2018-02-23  34.99  36.35  35.21  34.01  501915.41          3.03     10.03
# 2018-02-26  34.99  36.35  35.21  34.01  501915.41          3.03     10.03
# 2018-02-27  34.99  36.35  35.21  34.01  501915.41          3.03     10.03
#
#             turnover
# 2015-03-02      3.30
# 2015-03-03      4.76
# ...

# %%
# 对p_change进行求和
stock_rise = data['p_change']
# plot方法集成了前面直方图、条形图、饼图、折线图
stock_rise.cumsum()
# Out:
# 2018-02-27      2.68
# 2018-02-26      5.70
# 2018-02-23      8.12
# 2018-02-22      9.76
# 2018-02-14     11.81
#                ...
# 2015-03-06    114.70
# 2015-03-05    116.72
# 2015-03-04    118.29
# 2015-03-03    119.73
# 2015-03-02    122.35
# Name: p_change, Length: 643, dtype: float64

# %% [markdown]
# # 自定义运算
#
# - apply(func, axis=0)
#
#     func:自定义函数
#
#     axis=0:默认是列，axis=1为行进行运算
#
#     定义一个对列，最大值-最小值的函数

# %%
data['open']
# Out:
# 2018-02-27    23.53
# 2018-02-26    22.80
# 2018-02-23    22.88
# 2018-02-22    22.25
# 2018-02-14    21.49
#               ...
# 2015-03-06    13.17
# 2015-03-05    12.88
# 2015-03-04    12.80
# 2015-03-03    12.52
# 2015-03-02    12.25
# Name: open, Length: 643, dtype: float64

# %%
data['open'].apply(lambda x: x+10)
# Out:
# 2018-02-27    33.53
# 2018-02-26    32.80
# 2018-02-23    32.88
# 2018-02-22    32.25
# 2018-02-14    31.49
#               ...
# 2015-03-06    23.17
# 2015-03-05    22.88
# 2015-03-04    22.80
# 2015-03-03    22.52
# 2015-03-02    22.25
# Name: open, Length: 643, dtype: float64

# %%
data[['open', 'close']].apply(lambda x: x.max() - x.min(), axis=0)
# Out:
# 2018-02-27    0.63
# 2018-02-26    0.73
# 2018-02-23    0.06
# 2018-02-22    0.03
# 2018-02-14    0.43
#               ...
# 2015-03-06    1.11
# 2015-03-05    0.28
# 2015-03-04    0.10
# 2015-03-03    0.18
# 2015-03-02    0.27
# Length: 643, dtype: float64

# %%
data[['open', 'close']]
# Out:
#              open  close
# 2018-02-27  23.53  24.16
# 2018-02-26  22.80  23.53
# 2018-02-23  22.88  22.82
# 2018-02-22  22.25  22.28
# 2018-02-14  21.49  21.92
# ...           ...    ...
# 2015-03-06  13.17  14.28
# 2015-03-05  12.88  13.16
# 2015-03-04  12.80  12.90
# 2015-03-03  12.52  12.70
# 2015-03-02  12.25  12.52
#
# [643 rows x 2 columns]

# %%
data['open'].max()
# Out:
# 34.99

# %%
data['open'].min()
# Out:
# 12.25

# %%
data['close'].max()
# Out:
# 35.21

# %%
data['close'].min()
# Out:
# 12.36
